# %%
# Dependencies
import tweepy
import matplotlib.pyplot as plt
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd
import time
analyzer = SentimentIntensityAnalyzer()

# %%
# Set up Tweepy API Authentication
from wusiapikeys import twitter_plotbot
consumer_key= twitter_plotbot["consumer_key"]
consumer_secret= twitter_plotbot["consumer_secret"]
access_token= twitter_plotbot["access_token"]
access_token_secret= twitter_plotbot["access_token_secret"]

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(),wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
# read the team name from file
team_pd=pd.read_excel("Resources/MLS_Historical_Attendance.xlsx","MLS",index_col="Rank")
team_list = team_pd["Team"].tolist()

# %% [markdown]
# teams=['Atlanta United FC',
#  'Seattle Sounders',
#  'Toronto FC',
#  'Orlando City',
#  'New York City FC',
#  'Los Angeles Galaxy',
#  'Vancouver Whitecaps',
#  'New York Red Bulls',
#  'Portland Timbers',
#  'Minnesota United FC',
#  'Impact de Montréal',
#  'San Jose Earthquakes',
#  'Sporting Kansas City',
#  'New England Revolution',
#  'Real Salt Lake',
#  'D.C. United',
#  'Houston Dynamo',
#  'Chicago Fire',
#  'Philadelphia Union',
#  'Columbus Crew',
#  'Colorado Rapids',
#  'FC Dallas']
#
# hash_tags ={'Atlanta United FC':["#ATLUTD"],
#   'Seattle Sounders':["#Sounders"],
#  'Toronto FC':["#TFC"],
#  'Orlando City':["#OCSC"],
#  'New York City FC':["#NYCFC"],
#  'Los Angeles Galaxy':["#LAGalaxy"],
#  'Vancouver Whitecaps':["#VWFC"],
#  'New York Red Bulls':["#RBNY"],
#  'Portland Timbers':["#PTFC"],
#  'Minnesota United FC':["#MNUFC"],
#  'Impact de Montréal':["#IMFC"],
#  'San Jose Earthquakes':["#SJEartquakes"],
#  'Sporting Kansas City':["#SportingKC"],
#  'New England Revolution':["#NERevs"],
#  'Real Salt Lake':["#RSL"],
#  'D.C. United':["#DCU"],
#  'Houston Dynamo':["#HoustonDynamo","#foreverorange"],
#  'Chicago Fire':["#cf97"],
#  'Philadelphia Union':["#DOOP","#PhiladelphiaUnion"],
#  'Columbus Crew':["#SaveTheCrew","#CrewSC","#Crew96"],
#  'Colorado Rapids':["#Rapids96"],
#  'FC Dallas':["#FCDallas"]}

# %%
## team name list
teams=['Atlanta United FC', 'Seattle Sounders', 'Toronto FC', 'Orlando City', 'New York City FC', 'Los Angeles Galaxy', 'Vancouver Whitecaps', 'New York Red Bulls', 'Portland Timbers', 'Minnesota United FC', 'Impact de Montréal', 'San Jose Earthquakes', 'Sporting Kansas City', 'New England Revolution', 'Real Salt Lake', 'D.C. United', 'Houston Dynamo', 'Chicago Fire', 'Philadelphia Union', 'Columbus Crew', 'Colorado Rapids', 'FC Dallas']

## team name: hash_tags dictionary
hash_tags ={'Atlanta United FC':["#ATLUTD"], 'Seattle Sounders':["#Sounders"], 'Toronto FC':["#TFC"], 'Orlando City':["#OCSC"], 'New York City FC':["#NYCFC"], 'Los Angeles Galaxy':["#LAGalaxy"], 'Vancouver Whitecaps':["#VWFC"], 'New York Red Bulls':["#RBNY"], 'Portland Timbers':["#PTFC"], 'Minnesota United FC':["#MNUFC"], 'Impact de Montréal':["#IMFC"], 'San Jose Earthquakes':["#Quakes74"], 'Sporting Kansas City':["#SportingKC"], 'New England Revolution':["#NERevs"], 'Real Salt Lake':["#RSL"], 'D.C. United':["#DCU"], 'Houston Dynamo':["#HoustonDynamo","#foreverorange"], 'Chicago Fire':["#cf97"], 'Philadelphia Union':["#DOOP","#PhiladelphiaUnion"], 'Columbus Crew':["#SaveTheCrew","#CrewSC","#Crew96"], 'Colorado Rapids':["#Rapids96"], 'FC Dallas':["#FCDallas"]}

# %%
# define function for search hashtag and conduct sentimental analysis
# return the average sentimental analysis score for all hash tags
def senti_analysis(hash_tags=[]):
    
    senti_score=[] #initialize score list
    count_of_tweets=0
    
    for hash_tag in hash_tags:
        print(hash_tag)
        
        last_id=None #initialize last id searched
        
        for i in range(1,6): ## do 5 searches for each hash tag
            print(f"search{i}------------------------------------------------------------------")
            try:
                public_tweets = api.search(q=hash_tag,count=100,max_id=last_id)["statuses"] ## search 100 tweets per search
                #print(f"{len(public_tweets)}")
                print(f"last twitter tweeted at {public_tweets[0]['created_at']}")

                last_id=public_tweets[-1]["id"] # get the last id for next search
                
                if i==1:
                    latest_twitter = public_tweets[0]["created_at"] 
                
                earliest_twitter = public_tweets[-1]["created_at"] 
                
                count_of_tweets += len(public_tweets)

                for tweet in public_tweets:
                    result = analyzer.polarity_scores(tweet["text"])
                    senti_score.append(result["compound"])
                    
            except Exception as e:
                print(f"error: {e}")

            time.sleep(1) #pause for 1 second
    
    return np.mean(senti_score),count_of_tweets,latest_twitter,earliest_twitter

# %%
senti_score_ls=[] # initialize a list to store sentimental analysis result for all teams

for team in teams:
    team_hash_tag = hash_tags[team]
    #print(team_hash_tag)
    
    senti_score,count_of_tweets,latest_twitter,earliest_twitter = senti_analysis(team_hash_tag)
    
    senti_score_ls.append({"team name":team,
                           "average polarity score":senti_score,
                           "number of tweets":count_of_tweets,
                           "from":earliest_twitter,
                           "to":latest_twitter,})
# Out:
# #ATLUTD
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:09:34 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 14:52:32 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 02:13:58 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 20:06:29 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 11:38:15 +0000 2018
# #Sounders
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:07:21 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 04:35:56 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 03:47:02 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 18:59:34 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Mon Jul 23 00:27:58 +0000 2018
# #TFC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:04:00 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 09:53:02 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 01:07:01 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 16:26:58 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 04:11:51 +0000 2018
# #OCSC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:02:38 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 15:10:25 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 15:20:11 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 21:58:48 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 12:42:07 +0000 2018
# #NYCFC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:20:13 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 16:11:25 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 02:02:21 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 20:39:44 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 17:53:00 +0000 2018
# #LAGalaxy
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:19:09 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 20:02:52 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 16:21:34 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 07:26:44 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 03:10:39 +0000 2018
# #VWFC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:16:20 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 18:48:53 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 15:09:22 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 12:30:10 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 08:15:55 +0000 2018
# #RBNY
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:20:50 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 19:40:05 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 17:59:30 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 16:39:39 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 15:22:00 +0000 2018
# #PTFC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 18:54:16 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 04:37:59 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 19 17:43:34 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Wed Jul 18 08:51:25 +0000 2018
# search5------------------------------------------------------------------
# error: list index out of range
# #MNUFC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:04:50 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 22:48:37 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 03:02:42 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 15:05:54 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Mon Jul 23 23:07:57 +0000 2018
# #IMFC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:20:27 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:51:14 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:28:26 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:13:07 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 20:55:58 +0000 2018
# #Quakes74
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:08:55 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 04:57:15 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 03:33:20 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 01:42:57 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 22:34:57 +0000 2018
# #SportingKC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:42:23 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 21:19:19 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Mon Jul 23 20:57:50 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Fri Jul 20 02:24:08 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 19 06:28:56 +0000 2018
# #NERevs
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:36:44 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 03:21:10 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 19:07:33 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 00:27:23 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 14:11:08 +0000 2018
# #RSL
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:17:17 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 14:30:42 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Mon Jul 23 18:33:01 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 19:13:27 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 09:25:04 +0000 2018
# #DCU
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:20:25 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 18:21:40 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 14:55:34 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 10:29:15 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 04:19:08 +0000 2018
# #HoustonDynamo
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 20:43:14 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 17:33:33 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 19 02:29:05 +0000 2018
# search4------------------------------------------------------------------
# error: list index out of range
# search5------------------------------------------------------------------
# error: list index out of range
# #foreverorange
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:10:21 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 01:45:26 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 18:18:45 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 18:16:21 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Mon Jul 23 00:38:37 +0000 2018
# #cf97
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:20:46 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 19:05:22 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 17:04:30 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 14:00:02 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 04:25:26 +0000 2018
# #DOOP
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:59:36 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 05:09:06 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 03:11:35 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 02:45:35 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 01:45:06 +0000 2018
# #PhiladelphiaUnion
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:22:01 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Sat Jul 21 21:45:11 +0000 2018
# search3------------------------------------------------------------------
# error: list index out of range
# search4------------------------------------------------------------------
# error: list index out of range
# search5------------------------------------------------------------------
# error: list index out of range
# #SaveTheCrew
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:15:52 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 19:01:04 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 15:41:18 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 11:45:01 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 01:47:23 +0000 2018
# #CrewSC
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:23:20 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 17:36:29 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 23:56:24 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 14:22:13 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 23:49:36 +0000 2018
# #Crew96
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:15:17 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 16:44:39 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Mon Jul 23 04:17:28 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 07:47:07 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Sun Jul 22 02:32:15 +0000 2018
# #Rapids96
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 21:43:12 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 15:01:54 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 03:22:01 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 02:29:00 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 01:26:59 +0000 2018
# #FCDallas
# search1------------------------------------------------------------------
# last twitter tweeted at Thu Jul 26 22:20:03 +0000 2018
# search2------------------------------------------------------------------
# last twitter tweeted at Wed Jul 25 19:23:48 +0000 2018
# search3------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 20:43:49 +0000 2018
# search4------------------------------------------------------------------
# last twitter tweeted at Tue Jul 24 08:38:35 +0000 2018
# search5------------------------------------------------------------------
# last twitter tweeted at Mon Jul 23 15:48:38 +0000 2018

# %%
# convert the result into panda dataframe
senti_score_df = pd.DataFrame(senti_score_ls)

#set index
senti_score_df.set_index("team name",inplace=True)
senti_score_df = senti_score_df[["average polarity score","number of tweets","from","to"]]

#add hash tag to the table
hash_tag_df = pd.Series(hash_tags,name="hash tag").to_frame()
hash_tag_df

final_df=senti_score_df.merge(hash_tag_df,right_index=True,left_index=True)
final_df
# Out:
#                         average polarity score  number of tweets  \
# team name
# Atlanta United FC                     0.193469               500
# Seattle Sounders                      0.205986               500
# Toronto FC                            0.143788               486
# Orlando City                         -0.018393               500
# New York City FC                      0.189508               500
# Los Angeles Galaxy                    0.167275               500
# Vancouver Whitecaps                   0.326139               464
# New York Red Bulls                    0.160031               500
# Portland Timbers                      0.154364               339
# Minnesota United FC                   0.232837               500
# Impact de Montréal                   -0.013391               500
# San Jose Earthquakes                  0.153629               500
# Sporting Kansas City                  0.138364               500
# New England Revolution                0.151610               500
# Real Salt Lake                        0.028082               457
# D.C. United                           0.128470               500
# Houston Dynamo                        0.122715               732
# Chicago Fire                          0.144655               500
# Philadelphia Union                    0.203439               652
# Columbus Crew                         0.198212              1500
# Colorado Rapids                       0.190736               500
# FC Dallas                             0.105040               500
#
#                                                   from  \
# team name
# Atlanta United FC       Tue Jul 24 22:49:32 +0000 2018
# Seattle Sounders        Sat Jul 21 22:04:54 +0000 2018
# Toronto FC              Tue Jul 24 15:24:44 +0000 2018
# Orlando City            Sun Jul 22 04:24:35 +0000 2018
# New York City FC        Wed Jul 25 16:55:05 +0000 2018
# Los Angeles Galaxy      Wed Jul 25 22:40:56 +0000 2018
# Vancouver Whitecaps     Thu Jul 26 05:59:57 +0000 2018
# New York Red Bulls      Thu Jul 26 14:06:15 +0000 2018
# Portland Timbers        Mon Jul 16 19:50:58 +0000 2018
# Minnesota United FC     Mon Jul 23 18:27:35 +0000 2018
# Impact de Montréal      Thu Jul 26 20:46:04 +0000 2018
# San Jose Earthquakes    Mon Jul 23 22:29:27 +0000 2018
# Sporting Kansas City    Thu Jul 19 02:03:08 +0000 2018
# New England Revolution  Tue Jul 24 02:15:56 +0000 2018
# Real Salt Lake          Sun Jul 22 04:00:36 +0000 2018
# D.C. United             Thu Jul 26 03:25:11 +0000 2018
# Houston Dynamo          Sun Jul 22 07:09:16 +0000 2018
# Chicago Fire            Thu Jul 26 01:26:53 +0000 2018
# Philadelphia Union      Mon Jul 16 18:41:22 +0000 2018
# Columbus Crew           Sat Jul 21 16:05:11 +0000 2018
# Colorado Rapids         Tue Jul 24 14:35:06 +0000 2018
# FC Dallas               Sun Jul 22 23:58:59 +0000 2018
#
#                                                     to  \
# team name
# Atlanta United FC       Thu Jul 26 22:09:34 +0000 2018
# Seattle Sounders        Thu Jul 26 22:07:21 +0000 2018
# Toronto FC              Thu Jul 26 22:04:00 +0000 2018
# Orlando City            Thu Jul 26 22:02:38 +0000 2018
# New York City FC        Thu Jul 26 22:20:13 +0000 2018
# Los Angeles Galaxy      Thu Jul 26 22:19:09 +0000 2018
# Vancouver Whitecaps     Thu Jul 26 22:16:20 +0000 2018
# New York Red Bulls      Thu Jul 26 22:20:50 +0000 2018
# Portland Timbers        Thu Jul 26 18:54:16 +0000 2018
# Minnesota United FC     Thu Jul 26 22:04:50 +0000 2018
# Impact de Montréal      Thu Jul 26 22:20:27 +0000 2018
# San Jose Earthquakes    Thu Jul 26 22:08:55 +0000 2018
# Sporting Kansas City    Thu Jul 26 21:42:23 +0000 2018
# New England Revolution  Thu Jul 26 21:36:44 +0000 2018
# Real Salt Lake          Thu Jul 26 22:17:17 +0000 2018
# D.C. United             Thu Jul 26 22:20:25 +0000 2018
# Houston Dynamo          Thu Jul 26 22:10:21 +0000 2018
# Chicago Fire            Thu Jul 26 22:20:46 +0000 2018
# Philadelphia Union      Thu Jul 26 21:22:01 +0000 2018
# Columbus Crew           Thu Jul 26 22:15:17 +0000 2018
# Colorado Rapids         Thu Jul 26 21:43:12 +0000 2018
# FC Dallas               Thu Jul 26 22:20:03 +0000 2018
#
#                                                 hash tag
# team name
# Atlanta United FC                              [#ATLUTD]
# Seattle Sounders                             [#Sounders]
# Toronto FC                                        [#TFC]
# Orlando City                                     [#OCSC]
# New York City FC                                [#NYCFC]
# Los Angeles Galaxy                           [#LAGalaxy]
# Vancouver Whitecaps                              [#VWFC]
# New York Red Bulls                               [#RBNY]
# Portland Timbers                                 [#PTFC]
# Minnesota United FC                             [#MNUFC]
# Impact de Montréal                               [#IMFC]
# San Jose Earthquakes                         [#Quakes74]
# Sporting Kansas City                       [#SportingKC]
# New England Revolution                         [#NERevs]
# Real Salt Lake                                    [#RSL]
# D.C. United                                       [#DCU]
# Houston Dynamo          [#HoustonDynamo, #foreverorange]
# Chicago Fire                                     [#cf97]
# Philadelphia Union           [#DOOP, #PhiladelphiaUnion]
# Columbus Crew           [#SaveTheCrew, #CrewSC, #Crew96]
# Colorado Rapids                              [#Rapids96]
# FC Dallas                                    [#FCDallas]

# %%
#export result to csv file
final_df.to_csv("Output/sentimental analysis result.csv")
