# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load CSVs
age_df_2016 = pd.read_csv("Output/age_data_2016.csv")

ethnicity_df_2016 = pd.read_csv("Output/ethnicity_data_2016.csv")

mls_attendance = pd.read_csv("Resources/MLS_2017_Attendance.csv")

# %%
# Clean the data frames

age_df = age_df_2016.loc[:, ["City & State","Total Population","Age 18 to 29","Age 30 to 44"]]

ethnicity_df = ethnicity_df_2016.loc[:, ["City & State","Total Population","White","Black/Afro-American","Latino","Asian"]]

# %%
mls_attendance = mls_attendance.dropna()

mls_attendance = mls_attendance.loc[:,["Team","Average"]]

mls_attendance
# Out:
#                       Team  Average
# 0        Atlanta United FC  48200.0
# 1         Seattle Sounders  43666.0
# 3             Orlando City  25028.0
# 4         New York City FC  22321.0
# 5       Los Angeles Galaxy  22246.0
# 7       New York Red Bulls  21175.0
# 8         Portland Timbers  21144.0
# 9      Minnesota United FC  20538.0
# 11    San Jose Earthquakes  19875.0
# 12    Sporting Kansas City  19537.0
# 13  New England Revolution  19367.0
# 14             D.C. United  18157.0
# 15          Real Salt Lake  18781.0
# 16          Houston Dynamo  17500.0
# 17            Chicago Fire  17383.0
# 18      Philadelphia Union  16812.0
# 19           Columbus Crew  15439.0
# 20         Colorado Rapids  15322.0
# 21               FC Dallas  15122.0

# %%
# Create column to hold percentile calculation for first age group and format it
age_df["Age % 18 to 29"] = age_df["Age 18 to 29"] / age_df["Total Population"] * 100
#age_df["Age % 18 to 29"] = age_df["Age % 18 to 29"].map("{:.1f}".format)

# Create column to hold percentile calculation for second age group and format it
age_df["Age % 30 to 44"] = age_df["Age 30 to 44"] / age_df["Total Population"] * 100
#age_df["Age % 30 to 44"] = age_df["Age % 30 to 44"].map("{:.1f}".format)

age_df
# Out:
#                              City & State  Total Population  Age 18 to 29  \
# 0                   Atlanta city, Georgia            456378        111563
# 1                Seattle city, Washington            668849        153546
# 2                   Orlando city, Florida            263306         57282
# 3                 New York city, New York           8461961       1598367
# 4                 Carson city, California             92780         16827
# 5                 Newark city, New Jersey            280139         56080
# 6                   Portland city, Oregon            620589        112933
# 7             Minneapolis city, Minnesota            404670        105223
# 8               San Jose city, California           1009363        171082
# 9                Kansas City city, Kansas            149755         25039
# 10          Foxborough CDP, Massachusetts              5491           615
# 11                       Sandy city, Utah             93141         14245
# 12  Washington city, District of Columbia            659009        159451
# 13                    Houston city, Texas           2240582        442457
# 14           Bridgeview village, Illinois             16381          2275
# 15             Chester city, Pennsylvania             34056          8459
# 16                    Columbus city, Ohio            837038        195925
# 17           Commerce City city, Colorado             51731          7365
# 18                     Frisco city, Texas            145646         13487
#
#     Age 30 to 44  Age % 18 to 29  Age % 30 to 44
# 0         109761       24.445306       24.050458
# 1         174781       22.956751       26.131608
# 2          64564       21.754916       24.520520
# 3        1890517       18.888849       22.341358
# 4          17290       18.136452       18.635482
# 5          62773       20.018634       22.407805
# 6         165930       18.197712       26.737503
# 7          94989       26.002175       23.473200
# 8         228996       16.949502       22.687180
# 9          30355       16.719976       20.269774
# 10          1010       11.200146       18.393735
# 11         18487       15.294017       19.848402
# 12        163879       24.195572       24.867490
# 13        508738       19.747414       22.705618
# 14          3307       13.888041       20.188023
# 15          5488       24.838501       16.114635
# 16        186045       23.406942       22.226589
# 17         12990       14.237111       25.110669
# 18         40450        9.260124       27.772819

# %%
# Create percentage calculations for ethnicity
ethnicity_df["White Percentage"] = ethnicity_df["White"] / ethnicity_df["Total Population"] * 100
ethnicity_df["Black Percentage"] = ethnicity_df["Black/Afro-American"] / ethnicity_df["Total Population"] * 100
ethnicity_df["Latino Percentage"] = ethnicity_df["Latino"] / ethnicity_df["Total Population"] * 100
ethnicity_df["Asian Percentage"] = ethnicity_df["Asian"] / ethnicity_df["Total Population"] * 100

# Format new columns
#ethnicity_df["White Percentage"] = ethnicity_df["White Percentage"].map("{:.1f}".format)
#ethnicity_df["Black Percentage"] = ethnicity_df["Black Percentage"].map("{:.1f}".format)
#ethnicity_df["Latino Percentage"] = ethnicity_df["Latino Percentage"].map("{:.1f}".format)
#ethnicity_df["Asian Percentage"] = ethnicity_df["Asian Percentage"].map("{:.1f}".format)

ethnicity_df
# Out:
#                              City & State  Total Population    White  \
# 0                   Atlanta city, Georgia            456378   182794
# 1                Seattle city, Washington            668849   462673
# 2                   Orlando city, Florida            263306   160607
# 3                 New York city, New York           8461961  3644982
# 4                 Carson city, California             92780    27282
# 5                 Newark city, New Jersey            280139    68226
# 6                   Portland city, Oregon            620589   482410
# 7             Minneapolis city, Minnesota            404670   262130
# 8               San Jose city, California           1009363   425883
# 9                Kansas City city, Kansas            149755    88953
# 10          Foxborough CDP, Massachusetts              5491     4975
# 11                       Sandy city, Utah             93141    83923
# 12  Washington city, District of Columbia            659009   266035
# 13                    Houston city, Texas           2240582  1305482
# 14           Bridgeview village, Illinois             16381    14061
# 15             Chester city, Pennsylvania             34056     6864
# 16                    Columbus city, Ohio            837038   511628
# 17           Commerce City city, Colorado             51731    43617
# 18                     Frisco city, Texas            145646   103681
#
#     Black/Afro-American   Latino    Asian  White Percentage  Black Percentage  \
# 0                239005    21838    18235         40.053202         52.369965
# 1                 47493    43868    94619         69.174507          7.100706
# 2                 69572    77009    10109         60.996331         26.422489
# 3               2064927  2457945  1159883         43.074909         24.402464
# 4                 19830    37011    23963         29.405044         21.373141
# 5                140750   100950     4914         24.354338         50.242915
# 6                 35465    60040    47045         77.734217          5.714732
# 7                 76070    38832    23911         64.776237         18.798033
# 8                 31096   329135   344188         42.193245          3.080755
# 9                 37530    43727     5786         59.399018         25.060933
# 10                  400      225      114         90.602805          7.284648
# 11                  609     8021     2949         90.103177          0.653847
# 12               318598    69106    24036         40.368948         48.345015
# 13               511398   992886   149265         58.265308         22.824338
# 14                  647     2783      849         85.837250          3.949698
# 15                24268     4056      200         20.155039         71.259103
# 16               234021    48331    41204         61.123629         27.958229
# 17                 1640    23598      992         84.315014          3.170246
# 18                11025    17324    22140         71.186988          7.569724
#
#     Latino Percentage  Asian Percentage
# 0            4.785069          3.995591
# 1            6.558730         14.146541
# 2           29.246960          3.839259
# 3           29.046990         13.707024
# 4           39.891140         25.827765
# 5           36.035682          1.754129
# 6            9.674680          7.580702
# 7            9.595967          5.908765
# 8           32.608190         34.099526
# 9           29.199025          3.863644
# 10           4.097614          2.076125
# 11           8.611675          3.166167
# 12          10.486351          3.647295
# 13          44.313754          6.661885
# 14          16.989195          5.182834
# 15          11.909796          0.587268
# 16           5.774051          4.922596
# 17          45.616748          1.917612
# 18          11.894594         15.201241

# %%
# Create bar chart for age to show categorical percentages between cities

ind = np.arange(len(age_df))
width = 0.4
tick_locations = [value+0.4 for value in ind]

plt.figure(figsize=(20,5))
fig, ax = plt.subplots()

age1829 = ax.bar(ind,age_df["Age % 18 to 29"], width, color='y', align='edge')
age3044 = ax.bar(ind + width,age_df["Age % 30 to 44"], width, color='b', align='edge')

plt.ylabel('Percentage of Population')
plt.title('Percentage of Population Within Age Groups For MLS Cities')
plt.xticks(tick_locations, age_df["City & State"], rotation='vertical')

plt.show()

# %%
# Age scatter plot

plt.scatter(age_df["Age % 18 to 29"], mls_attendance["Average"], marker='o',facecolors='b',edgecolors='black')

plt.show()
